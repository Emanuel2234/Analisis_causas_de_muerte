# %% [markdown]
# <a href="https://colab.research.google.com/github/Emanuel2234/Analisis_causas_de_muerte/blob/main/An%C3%A1lisis_de_datos_sobre_Causas_de_muerte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#se importan las librerias
import pandas as pd
import numpy as np

# %%
#se importa el dataset
df = pd.read_csv('/content/cause_of_deaths.csv')

# %% [markdown]
# # Fase 1: entendimiento del negocio

# %%
#identicamos las columnas
df.columns
# Out:
# Index(['Country/Territory', 'Code', 'Year', 'Meningitis',
#        'Alzheimer's Disease and Other Dementias', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis'],
#       dtype='object')

# %%
df.shape
# Out:
# (6120, 34)

# %% [markdown]
# **Se logra identificar loas 6120 registros en filas y las 34 columnas que serian las causas de muerte**

# %%
df.head(31)  #estos datos se basan desde el año 1990 hasta el 2019 para cada pais
# Out:
#    Country/Territory Code  Year  Meningitis  \
# 0        Afghanistan  AFG  1990        2159
# 1        Afghanistan  AFG  1991        2218
# 2        Afghanistan  AFG  1992        2475
# 3        Afghanistan  AFG  1993        2812
# 4        Afghanistan  AFG  1994        3027
# 5        Afghanistan  AFG  1995        3102
# 6        Afghanistan  AFG  1996        3193
# 7        Afghanistan  AFG  1997        3304
# 8        Afghanistan  AFG  1998        3281
# 9        Afghanistan  AFG  1999        3200
# 10       Afghanistan  AFG  2000        3105
# 11       Afghanistan  AFG  2001        3063
# 12       Afghanistan  AFG  2002        2990
# 13       Afghanistan  AFG  2003        3300
# 14       Afghanistan  AFG  2004        3350
# 15       Afghanistan  AFG  2005        3238
# 16       Afghanistan  AFG  2006        3098
# 17       Afghanistan  AFG  2007        2933
# 18       Afghanistan  AFG  2008        2731
# 19       Afghanistan  AFG  2009        2460
# ...

# %% [markdown]
# ##**Se logra apreciar que la columna "Country/Territory" y "Code" son las columnas categoricas para el resto de variables son numericas**

# %%
df['Country/Territory'].value_counts() #claramente se cuentan 30 para cada pais porque se repite por cada año los cuales son entre 1990 y 2019(se muestra la categoria y distribucion)
# Out:
# Country/Territory
# Afghanistan       30
# Albania           30
# Algeria           30
# American Samoa    30
# Andorra           30
#                   ..
# Venezuela         30
# Vietnam           30
# Yemen             30
# Zambia            30
# Zimbabwe          30
# Name: count, Length: 204, dtype: int64

# %%
df['Country/Territory'].value_counts().count()#muestra la cantidad
# Out:
# np.int64(204)

# %%
df['Code'].value_counts()
# Out:
# Code
# AFG    30
# ALB    30
# DZA    30
# ASM    30
# AND    30
#        ..
# VEN    30
# VNM    30
# YEM    30
# ZMB    30
# ZWE    30
# Name: count, Length: 204, dtype: int64

# %%
df['Code'].value_counts().count()
# Out:
# np.int64(204)

# %%
df.isna().sum() #no pose nulos
# Out:
# Country/Territory                             0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# ...

# %%
df.isnull().sum() #no posee valores nulos
# Out:
# Country/Territory                             0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer's Disease and Other Dementias       0
# Parkinson's Disease                           0
# Nutritional Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal Violence                        0
# Maternal Disorders                            0
# HIV/AIDS                                      0
# Drug Use Disorders                            0
# Tuberculosis                                  0
# Cardiovascular Diseases                       0
# Lower Respiratory Infections                  0
# Neonatal Disorders                            0
# Alcohol Use Disorders                         0
# Self-harm                                     0
# Exposure to Forces of Nature                  0
# ...

# %%
df.describe().round() # estadistica a columnas numericas
# Out:
#          Year  Meningitis  Alzheimer's Disease and Other Dementias  \
# count  6120.0      6120.0                                   6120.0
# mean   2004.0      1720.0                                   4864.0
# std       9.0      6672.0                                  18221.0
# min    1990.0         0.0                                      0.0
# 25%    1997.0        15.0                                     90.0
# 50%    2004.0       109.0                                    666.0
# 75%    2012.0       847.0                                   2456.0
# max    2019.0     98358.0                                 320715.0
#
#        Parkinson's Disease  Nutritional Deficiencies   Malaria  Drowning  \
# count               6120.0                    6120.0    6120.0    6120.0
# mean                1173.0                    2254.0    4141.0    1683.0
# std                 4616.0                   10484.0   18428.0    8877.0
# ...

# %% [markdown]
# **El dataset tiene 6120 registros por variable donde se evaluaron desde los años 1990 hasta el 2019**

# %%
df.dropna() #se eliminan nulos

# %%
df_limpio = df.dropna() #aun no aplicado

# %%
df_limpio.to_csv("/content/causas_muerte_limpio.csv") #solo ejecutar al finalizar el limpieza de datos

# %%
df.groupby("Year")["Malaria"].sum().sort_values(ascending=False)
# Out:
# Year
# 2004    960784
# 2003    959654
# 2006    941746
# 2005    940540
# 2007    940193
# 2008    932910
# 2002    929195
# 2009    917796
# 2001    912709
# 2010    909814
# 1998    901338
# 1999    893788
# 1997    892946
# 2000    882055
# 1996    872476
# 2011    868564
# 1995    862626
# 1993    862216
# 1991    858984
# 1992    856415
# 1994    855671
# 1990    840297
# 2012    806183
# 2013    751776
# 2014    724324
# 2015    702890
# 2016    660364
# 2019    643201
# 2018    631568
# 2017    629653
# Name: Malaria, dtype: int64

# %%
df.groupby("Country/Territory")["Malaria"].sum().sort_values(ascending=False)
# Out:
# Country/Territory
# Nigeria                         6422063
# Democratic Republic of Congo    2557219
# India                           2439244
# Uganda                          1265629
# Burkina Faso                     950762
#                                  ...
# United Arab Emirates                  0
# Ukraine                               0
# Tuvalu                                0
# United Kingdom                        0
# Uruguay                               0
# Name: Malaria, Length: 204, dtype: int64

# %% [markdown]
# ##**Se logra ver que los 5 paises con mas casos de muerte por malaria son Nigeria, Republica del Congo, India, Uganda y Burkina Faso**

# %%
df.groupby("Country/Territory")["Chronic Respiratory Diseases"].sum().sort_values(ascending=False)
# Out:
# Country/Territory
# China            36676826
# India            25232974
# United States     4949052
# Indonesia         2559457
# Pakistan          2276479
#                    ...
# San Marino            229
# Cook Islands          213
# Nauru                 128
# Niue                   45
# Tokelau                34
# Name: Chronic Respiratory Diseases, Length: 204, dtype: int64

# %% [markdown]
# ##**La mayor muerte por casos respiratorios estan entre china y la india superando el millon de muertos**
